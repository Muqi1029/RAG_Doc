# %%
from src.dataset import QueryDataset, get_dataloader

# %%
dataset = QueryDataset("input")

# %%
dataloader = get_dataloader("input")

# %%
dataset[0]
# Out:
# ([-0.07963959872722626,
#   -0.002376474905759096,
#   0.017934560775756836,
#   0.0005617288989014924,
#   0.00026968281599693,
#   0.013167998753488064,
#   0.005420914385467768,
#   -0.03404034674167633,
#   0.0022181908134371042,
#   0.0030964715406298637,
#   -0.0007800551247783005,
#   0.019847257062792778,
#   -0.020087851211428642,
#   -0.024198083207011223,
#   -0.04805609956383705,
#   -0.020572906360030174,
#   0.010323548689484596,
#   -0.06279663741588593,
#   0.02207333967089653,
#   -0.05168735235929489,
#   0.005238552577793598,
#   0.018532302230596542,
#   0.01905778795480728,
#   0.014091987162828445,
#   0.050765905529260635,
#   0.03598678112030029,
#   -0.012150080874562263,
#   -0.02052917331457138,
#   0.00010390199167886749,
#   -0.028540728613734245,
#   0.006734429392963648,
#   0.035245150327682495,
#   0.08976459503173828,
#   -0.03476833179593086,
#   -0.042808014899492264,
#   -0.04162728041410446,
#   0.001452229218557477,
#   0.008532300591468811,
# ...

# %%
dataset[1]
